# %%
# %matplotlib notebook

# %%
# %rerun 2
# Out:
# === Executing: ===
# # %load stammfunktion.py
# # 01_stammfunktion.py
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.widgets import Slider
#
# fig, ax = plt.subplots(figsize=(6, 6))
# plt.title(r'$s\left( t\right) =\int v\left( t\right)dt$')
# plt.subplots_adjust(left=0.12, bottom=0.22)
# plt.xlim(0, 5)
# plt.ylim(0, 5.5)
# plt.xlabel('t')
# plt.ylabel('v, s')
# t = np.arange(0, 5, 0.001)
#
#
# def f(t, v=1):
#     return 0 * t + v
#
#
# def F(t, v=1):
#     return v * t
#
#
# fx, Fx = plt.plot(t, f(t), t, F(t))
# fx.set(color='red', lw=2)
# Fx.set(color='blue', lw=2)
# # x-, y-Position, Laenge, Hoehe
# xyA = plt.axes([0.1, 0.10, 0.8, 0.03])
# # Slider-Objekt erzeugen
# sldA = Slider(xyA, 'v', 0, 5.0, valinit=1, valstep=0.1)
#
#
# def update(val):
#     v = sldA.val
#     fx.set_data(t, f(t, v))
#     Fx.set_data(t, F(t, v))
#
#
# # Aenderungen abfragen
# sldA.on_changed(update)
# ax.grid(True)
# plt.show()
# === Output: ===
# <img src="data:image/png;base64,..." width="600">

# %%
# %pwd
# Out:
# '/Users/jonporsche/Documents/Dev Projects.nosync/python-learning/kapitel-11-integralrechnung'

# %%
# %ls
# Out:
# Integrale.ipynb   Untitled.ipynb    stammfunktion.py

# %%
# %cd ..
# Out:
# /Users/jonporsche/Documents/Dev Projects.nosync/python-learning

# %%
# %ls
# Out:
# Dockerfile
# README.md
# analysis/
# angewandte-mathe/
# docker-compose.yml
# kapitel-1-einfuehrung/
# kapitel-10-reihen/
# kapitel-11-integralrechnung/
# kapitel-2-datentypen-und-datenstrukturen/
# kapitel-3-programmstrukturen/
# kapitel-4-erweiterungsmodule/
# kapitel-5-zahlen/
# kapitel-6-gleichungssysteme/
# kapitel-7-folgen/
# requirements.txt

# %%
# %cd kapitel-4-erweiterungsmodule/
# Out:
# /Users/jonporsche/Documents/Dev Projects.nosync/python-learning/kapitel-4-erweiterungsmodule

# %%
# %cd matplotlib/
# Out:
# /Users/jonporsche/Documents/Dev Projects.nosync/python-learning/kapitel-4-erweiterungsmodule/matplotlib

# %%
# %load funkplot1.py
# 03_funkplot1.py

import numpy as np
import matplotlib.pyplot as plt

# Erzeugung eines 1-dimensionales Array vom Typ <class 'numpy.narray'>
# mit 500 Gleitpunktzahlen für den Wertebereich der unabhängigen Variablen x
x = np.linspace(0, 10, 500)
y = x ** 2

plt.plot(x, y, linewidth=2, linestyle='-', color='b')
plt.show()

# %%
# %matplotlib notebook
# %rerun 14
# Out:
# === Executing: ===
# # %load funkplot1.py
# # 03_funkplot1.py
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Erzeugung eines 1-dimensionales Array vom Typ <class 'numpy.narray'>
# # mit 500 Gleitpunktzahlen für den Wertebereich der unabhängigen Variablen x
# x = np.linspace(0, 10, 500)
# y = x ** 2
#
# plt.plot(x, y, linewidth=2, linestyle='-', color='b')
# plt.show()
# === Output: ===
# <img src="data:image/png;base64,..." width="640">

# %%
# %load funkplot2.py
# 04_funkplot2.py

import numpy as np
import matplotlib.pyplot as plt

# x-Werte
x = np.linspace(0, 10, 500)

# mathematische Funktionen
y1 = x ** 2
y2 = -10 * x + 100

# Funktionsplot
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title('Funkionsplot')
ax.plot(x, y1, 'r--', lw=2, label='$y_1=x^2$')
ax.plot(x, y2, 'b-', lw=2, label='$y_2=10\cdot x+100$')
ax.plot(6.18, 38.2, 'ro')
ax.set_xlabel('x')
ax.set_ylabel('y', rotation=True)
ax.legend(loc='best')
ax.text(6.5, 37, 'Schnittpunkt')
ax.set_xticks(np.arange(0, 11, 1))
ax.set_yticks(np.arange(0, 110, 10))
ax.grid(True)
plt.show()

# %%
# %matplotlib notebook
# %rerun 15
# Out:
# === Executing: ===
# %matplotlib notebook
# %rerun 14
# === Output: ===
# === Executing: ===
# # %load funkplot1.py
# # 03_funkplot1.py
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Erzeugung eines 1-dimensionales Array vom Typ <class 'numpy.narray'>
# # mit 500 Gleitpunktzahlen für den Wertebereich der unabhängigen Variablen x
# x = np.linspace(0, 10, 500)
# y = x ** 2
#
# plt.plot(x, y, linewidth=2, linestyle='-', color='b')
# plt.show()
# === Output: ===
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# x-Werte
x = np.linspace(0, 10, 500)

# mathematische Funktionen
y1 = x ** 2
y2 = -10 * x + 100

# Funktionsplot
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title('Funkionsplot')
ax.plot(x, y1, 'r--', lw=2, label='$y_1=x^2$')
ax.plot(x, y2, 'b-', lw=2, label='$y_2=10\cdot x+100$')
ax.plot(6.18, 38.2, 'ro')
ax.set_xlabel('x')
ax.set_ylabel('y', rotation=True)
ax.legend(loc='best')
ax.text(6.5, 37, 'Schnittpunkt')
ax.set_xticks(np.arange(0, 11, 1))
ax.set_yticks(np.arange(0, 110, 10))
ax.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# %pwd
# %cd ../..
# %pwd
# Out:
# /Users
# '/Users'

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('messwerte.csv')

df.plot()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('messwerte.csv')

df.plot(kind='scatter', x='Date', y='Temperature')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/rv/pgv25mjd387bmjq_54gpqyrw0000gn/T/ipykernel_32266/1744328490.py in <module>
#       5 df = pd.read_csv('messwerte.csv')
#       6
# ----> 7 df.plot(kind='scatter', x='Date', y='Temperature')
#       8
#       9 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1114         scatter = ax.scatter(
#    1115             data[x].values,
# -> 1116             data[y].values,
#    1117             c=c_values,
#    1118             label=label,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Temperature'

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('messwerte.csv')

df.plot()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
